# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import urllib2
import urllib
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import json
import re
import seaborn as sns
from sklearn import tree
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import SGDClassifier

WeatherData = pd.read_csv("./Weather Data.csv");
WeatherData = pd.DataFrame(data = WeatherData)
CrimeData = pd.read_csv("./Crime Data.csv");
CrimeData = pd.DataFrame(data = CrimeData)
sns.__version__
# Out:
# '0.9.0'

# %%
print WeatherData.info()

plt.matshow(WeatherData.corr())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11522 entries, 0 to 11521
# Data columns (total 11 columns):
# DATE                      11522 non-null object
# Unnamed: 1                0 non-null float64
# HOURLYSKYCONDITIONS       11052 non-null object
# HOURLYVISIBILITY          11057 non-null object
# HOURLYDRYBULBTEMPF        10926 non-null object
# HOURLYRelativeHumidity    10926 non-null object
# HOURLYWindSpeed           11035 non-null object
# HOURLYStationPressure     11144 non-null object
# Unnamed: 8                0 non-null float64
# DAILYSunrise              11522 non-null int64
# DAILYSunset               11522 non-null int64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 990.2+ KB
# None

# %%
print CrimeData.info()
names = list(CrimeData)
#time_to_float can only be ran once
def time_to_float(time_str):
    return float(time_str.replace(":",""))
#CrimeData['occur_time'] = CrimeData['occur_time'].apply(time_to_float)
print CrimeData['occur_time']
sns.catplot(x="UC2 Literal", y="occur_time", hue="Avg Day", data=CrimeData, height = 25, aspect = .8);
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26758 entries, 0 to 26757
# Data columns (total 10 columns):
# Date                26758 non-null object
# occur_time          26758 non-null float64
# poss_date           26758 non-null object
# poss_time           26755 non-null object
# MaxOfnum_victims    26684 non-null float64
# Avg Day             26758 non-null object
# UC2 Literal         26758 non-null object
# neighborhood        25573 non-null object
# x                   26758 non-null float64
# y                   26758 non-null float64
# dtypes: float64(4), object(6)
# memory usage: 2.0+ MB
# None
# 0        235900.0
# 1        235900.0
# 2        235900.0
# 3        235900.0
# 4        235900.0
# 5        235800.0
# 6        235800.0
# 7        235800.0
# 8        235800.0
# 9        235700.0
# 10       235700.0
# 11       235700.0
# 12       235700.0
# 13       235700.0
# 14       235600.0
# 15       235600.0
# 16       235600.0
# 17       235500.0
# 18       235500.0
# 19       235500.0
# 20       235500.0
# 21       235500.0
# 22       235500.0
# 23       235500.0
# 24       235400.0
# 25       235400.0
# 26       235400.0
# 27       235300.0
# 28       235300.0
# 29       235300.0
#            ...
# 26728         0.0
# 26729         0.0
# 26730         0.0
# 26731         0.0
# 26732         0.0
# 26733         0.0
# 26734         0.0
# 26735         0.0
# 26736         0.0
# 26737         0.0
# 26738         0.0
# 26739         0.0
# 26740         0.0
# 26741         0.0
# 26742         0.0
# 26743         0.0
# 26744         0.0
# 26745         0.0
# 26746         0.0
# 26747         0.0
# 26748         0.0
# 26749         0.0
# 26750     34500.0
# 26751    193300.0
# 26752      3000.0
# 26753    125600.0
# 26754     72000.0
# 26755     45000.0
# 26756     21500.0
# 26757     95200.0
# Name: occur_time, Length: 26758, dtype: float64

# %%
CrimeWeatherData = [CrimeData, WeatherData]
CrimeWeatherData = pd.concat(CrimeWeatherData)
